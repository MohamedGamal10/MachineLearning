# %% [markdown]
# # Download images

# %%
# %%time
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
sess = sagemaker.Session()
BUCKET = sess.default_bucket()
PREFIX = 'input'
# Out:
# arn:aws:iam::165417668877:role/service-role/AmazonSageMaker-ExecutionRole-20210208T212103
# CPU times: user 1 s, sys: 172 ms, total: 1.18 s
# Wall time: 10.9 s

# %%
# !wget http://aws-tc-largeobjects.s3-us-west-2.amazonaws.com/DIG-TF-200-MLBEES-10-EN/dataset.zip 
# !unzip -qo dataset.zip
# Out:
# --2021-02-09 13:41:33--  http://aws-tc-largeobjects.s3-us-west-2.amazonaws.com/DIG-TF-200-MLBEES-10-EN/dataset.zip
# Resolving aws-tc-largeobjects.s3-us-west-2.amazonaws.com (aws-tc-largeobjects.s3-us-west-2.amazonaws.com)... 52.218.196.249
# Connecting to aws-tc-largeobjects.s3-us-west-2.amazonaws.com (aws-tc-largeobjects.s3-us-west-2.amazonaws.com)|52.218.196.249|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70375947 (67M) [application/x-zip-compressed]
# Saving to: ‘dataset.zip.1’
#
# dataset.zip.1       100%[===================>]  67.12M  9.96MB/s    in 7.5s
#
# 2021-02-09 13:41:40 (8.98 MB/s) - ‘dataset.zip.1’ saved [70375947/70375947]

# %%
# !unzip -l dataset.zip | tail -20
# Out:
#    251027  05-15-2019 19:21   9530124.jpg
#    110561  05-15-2019 19:21   9542264.jpg
#    312354  05-15-2019 19:21   9543188.jpg
#     76903  05-15-2019 19:21   9637165.jpg
#     48663  05-15-2019 19:21   9765741.jpg
#     66393  05-15-2019 19:21   9787032.jpg
#    273392  05-22-2019 21:58   output.manifest
#         0  06-01-2019 05:51   test/
#     83438  06-01-2019 05:51   test/22427594.jpg
#    152133  06-01-2019 05:51   test/22469656.jpg
#    205930  06-01-2019 05:51   test/22544384.jpg
#    137755  06-01-2019 05:51   test/22673445.jpg
#    124565  06-01-2019 05:51   test/22741822.jpg
#     39502  06-01-2019 05:51   test/22774999.jpg
#     39086  06-01-2019 05:51   test/22775000.jpg
#    149389  06-01-2019 05:51   test/22901964.jpg
#    103322  06-01-2019 05:51   test/22971237.jpg
#    109178  06-01-2019 05:51   test/23086755.jpg
# ---------                     -------
#  70635014                     512 files

# %% [markdown]
# # Upload images to S3

# %%
# !aws s3 sync --exclude="*" --include="[0-9]*.jpg" . s3://$BUCKET/$PREFIX/
# Out:
# warning: Skipping file /home/ec2-user/SageMaker/lost+found. File/Directory is not readable.
# upload: ./10022723.jpg to s3://sagemaker-us-east-1-165417668877/input/10022723.jpg
# upload: ./10006450.jpg to s3://sagemaker-us-east-1-165417668877/input/10006450.jpg
# upload: ./10631806.jpg to s3://sagemaker-us-east-1-165417668877/input/10631806.jpg
# upload: ./10059108.jpg to s3://sagemaker-us-east-1-165417668877/input/10059108.jpg
# upload: ./10311147.jpg to s3://sagemaker-us-east-1-165417668877/input/10311147.jpg
# upload: ./1063563.jpg to s3://sagemaker-us-east-1-165417668877/input/1063563.jpg
# upload: ./10250726.jpg to s3://sagemaker-us-east-1-165417668877/input/10250726.jpg
# upload: ./9787032.jpg to s3://sagemaker-us-east-1-165417668877/input/9787032.jpg

# %% [markdown]
# # manifest_file

# %%
labeling_job_name = 'bees-500'
augmented_manifest_file = 'output.manifest'

# %%
#replacing bucket name and prefix to right format
outputManifest = open("output.manifest", "rt")
#read file contents to string
manifest = outputManifest.read()
#replace all occurrences of the required string
replaceStr = BUCKET + '/' + PREFIX
manifest = manifest.replace('sagemaker-remars/datasets/na-bees/500', replaceStr)
#close the input file
outputManifest.close()
#open the input file in write mode
outputManifest = open("output.manifest", "wt")
#overrite the input file with the resulting data
outputManifest.write(manifest)
#close the file
outputManifest.close()

# %%
# !head -3 $augmented_manifest_file
# Out:
# {"source-ref":"s3://sagemaker-us-east-1-165417668877/input/10006450.jpg","bees-500":{"annotations":[{"class_id":0,"width":95.39999999999998,"top":256.2,"height":86.80000000000001,"left":177}],"image_size":[{"width":500,"depth":3,"height":500}]},"bees-500-metadata":{"job-name":"labeling-job/bees-500","class-map":{"0":"bee"},"human-annotated":"yes","objects":[{"confidence":0.75}],"creation-date":"2019-05-16T00:15:58.914553","type":"groundtruth/object-detection"}}
# {"source-ref":"s3://sagemaker-us-east-1-165417668877/input/10022723.jpg","bees-500":{"annotations":[{"class_id":0,"width":93.8,"top":228.8,"height":135,"left":126.8}],"image_size":[{"width":375,"depth":3,"height":500}]},"bees-500-metadata":{"job-name":"labeling-job/bees-500","class-map":{"0":"bee"},"human-annotated":"yes","objects":[{"confidence":0.82}],"creation-date":"2019-05-16T00:41:33.384412","type":"groundtruth/object-detection"}}
# {"source-ref":"s3://sagemaker-us-east-1-165417668877/input/10059108.jpg","bees-500":{"annotations":[{"class_id":0,"width":157.39999999999998,"top":188.60000000000002,"height":131.2,"left":110.8}],"image_size":[{"width":375,"depth":3,"height":500}]},"bees-500-metadata":{"job-name":"labeling-job/bees-500","class-map":{"0":"bee"},"human-annotated":"yes","objects":[{"confidence":0.8}],"creation-date":"2019-05-16T00:57:28.636681","type":"groundtruth/object-detection"}}

# %% [markdown]
# # Show images Data

# %%
import os
import boto3
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
from itertools import cycle

def show_annotated_image(img_path, bboxes):
    im = np.array(Image.open(img_path), dtype=np.uint8)
    
    # Create figure and axes
    fig,ax = plt.subplots(1)

    # Display the image
    ax.imshow(im)

    colors = cycle(['r', 'g', 'b', 'y', 'c', 'm', 'k', 'w'])
    
    for bbox in bboxes:
        # Create a Rectangle patch
        rect = patches.Rectangle((bbox['left'],bbox['top']),bbox['width'],bbox['height'],linewidth=1,edgecolor=next(colors),facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)

    plt.show()

# %%
# !pip -q install --upgrade pip
# !pip -q install jsonlines
import jsonlines
from itertools import islice

with jsonlines.open(augmented_manifest_file, 'r') as reader:
    for desc in islice(reader, 10):
        img_url = desc['source-ref']
        img_file = os.path.basename(img_url)
        file_exists = os.path.isfile(img_file)

        bboxes = desc[labeling_job_name]['annotations']
        show_annotated_image(img_file, bboxes)

# %% [markdown]
# # Spliting data

# %%
import json
import jsonlines
import numpy as np

with jsonlines.open('output.manifest', 'r') as reader:
    lines = list(reader)
    # Shuffle data in place.
    np.random.shuffle(lines)
    
dataset_size = len(lines)
num_training_samples = round(dataset_size*0.8)

train_data = lines[:num_training_samples]
validation_data = lines[num_training_samples:]

augmented_manifest_filename_train = 'train.manifest'

with open(augmented_manifest_filename_train, 'w') as f:
    for line in train_data:
        f.write(json.dumps(line))
        f.write('\n')

augmented_manifest_filename_validation = 'validation.manifest'

with open(augmented_manifest_filename_validation, 'w') as f:
    for line in validation_data:
        f.write(json.dumps(line))
        f.write('\n')
        
print(f'training samples: {num_training_samples}, validation samples: {len(lines)-num_training_samples}')
# Out:
# training samples: 400, validation samples: 100

# %% [markdown]
# # upload manifest to S3

# %%
pfx_training = PREFIX + '/training' if PREFIX else 'training'
# Defines paths for use in the training job request.
s3_train_data_path = 's3://{}/{}/{}'.format(BUCKET, pfx_training, augmented_manifest_filename_train)
s3_validation_data_path = 's3://{}/{}/{}'.format(BUCKET, pfx_training, augmented_manifest_filename_validation)

# !aws s3 cp train.manifest s3://$BUCKET/$pfx_training/
# !aws s3 cp validation.manifest s3://$BUCKET/$pfx_training/
# Out:
# upload: ./train.manifest to s3://sagemaker-us-east-1-165417668877/input/training/train.manifest
# upload: ./validation.manifest to s3://sagemaker-us-east-1-165417668877/input/training/validation.manifest

# %% [markdown]
# # Training Model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

training_image = get_image_uri(sess.boto_region_name, 'object-detection', repo_version='latest')
print (training_image)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/object-detection:1

# %%
s3_output_location = 's3://{}/{}/output'.format(BUCKET, pfx_training)

# %%
od_model = sagemaker.estimator.Estimator(training_image,
                                         role, 
                                         instance_count=1, 
                                         instance_type='ml.p3.2xlarge',
                                         volume_size = 50,
                                         max_run = 360000,
                                         input_mode= 'Pipe',
                                         output_path=s3_output_location,
                                         sagemaker_session=sess)

# %% [markdown]
# # hyperparameters

# %%
def set_hyperparameters():
    od_model.set_hyperparameters(base_network='resnet-50',
                                 use_pretrained_model=1,
                                 num_classes='1',
                                 mini_batch_size=1,
                                 epochs=100,               
                                 learning_rate=0.001,       
                                 lr_scheduler_factor=0.1,
                                 optimizer='sgd',
                                 momentum=0.9,
                                 weight_decay=0.0005,
                                 overlap_threshold=0.5,
                                 nms_threshold=0.45,
                                 image_shape=512,
                                 label_width=350,
                                 num_training_samples=400,
                                 early_stopping=True,
                                 early_stopping_min_epochs=50,
                                 early_stopping_patience=5,
                                 early_stopping_tolerance=0.01)

# %%
set_hyperparameters()

# %%
train_data = sagemaker.inputs.TrainingInput(s3_train_data_path, input_mode='Pipe' ,record_wrapping='RecordIO' ,
                                            distribution='FullyReplicated',s3_data_type='AugmentedManifestFile',
                                            attribute_names=["source-ref","bees-500"] )
validation_data = sagemaker.inputs.TrainingInput(s3_train_data_path, input_mode='Pipe' ,record_wrapping='RecordIO' ,
                                            distribution='FullyReplicated',s3_data_type='AugmentedManifestFile',
                                            attribute_names=["source-ref","bees-500"])
data_channels = {'train': train_data, 'validation': validation_data}

# %% [markdown]
# # Training Job

# %%
# %%time
od_model.fit(inputs=data_channels, logs=True)
# Out:
# 2021-02-10 08:10:36 Starting - Starting the training job...
# 2021-02-10 08:10:38 Starting - Launching requested ML instancesProfilerReport-1612944635: InProgress
# .........
# 2021-02-10 08:12:31 Starting - Preparing the instances for training......
# 2021-02-10 08:13:33 Downloading - Downloading input data
# 2021-02-10 08:13:33 Training - Downloading the training image........Docker entrypoint called with argument(s): train
# [02/10/2021 08:14:47 INFO 139810865182528] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [02/10/2021 08:14:47 INFO 139810865182528] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'use_pretrained_model': u'1', u'label_width': u'350', u'early_stopping_min_epochs': u'50', u'epochs': u'100', u'early_stopping_tolerance': u'0.01', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'400', u'num_classes': u'1', u'mini_batch_size': u'1', u'weight_decay': u'0.0005', u'early_stopping_patience': u'5', u'early_stopping': u'True', u'lr_scheduler_factor': u'0.1'}
# [02/10/2021 08:14:47 INFO 139810865182528] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'50', u'epochs': u'100', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'1', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'True', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'400', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.01', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'1', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [02/10/2021 08:14:47 INFO 139810865182528] Using default worker.
# [02/10/2021 08:14:47 INFO 139810865182528] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [02/10/2021 08:14:47 INFO 139810865182528] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [02/10/2021 08:14:47 INFO 139810865182528] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [02/10/2021 08:14:47 INFO 139810865182528] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [02/10/2021 08:14:47 INFO 139810865182528] Checkpoint loading and saving are disabled.
# [02/10/2021 08:14:47 INFO 139810865182528] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [02/10/2021 08:14:47 INFO 139810865182528] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [02/10/2021 08:14:47 INFO 139810865182528] nvidia-smi took: 0.0754950046539 secs to identify 1 gpus
# [02/10/2021 08:14:47 INFO 139810865182528] Number of GPUs being used: 1
# [02/10/2021 08:14:47 INFO 139810865182528] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [02/10/2021 08:14:47 INFO 139810865182528] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [02/10/2021 08:14:47 WARNING 139810865182528] Training images are resized to image shape (3, 512, 512)
# [08:14:47] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:41: ImageDetRecordIOParser: pipe:///opt/ml/input/data/train, use 7 threads for decoding..
# [02/10/2021 08:14:47 WARNING 139810865182528] Validation images are resized to image shape (3, 512, 512)
# [08:14:47] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:41: ImageDetRecordIOParser: pipe:///opt/ml/input/data/validation, use 7 threads for decoding..
# [02/10/2021 08:14:48 INFO 139810865182528] Number of GPUs being used: 1
# [02/10/2021 08:14:48 INFO 139810865182528] Using [gpu(0)] as training context.
# [02/10/2021 08:14:48 INFO 139810865182528] Number of GPUs being used: 1
# [02/10/2021 08:14:48 INFO 139810865182528] Create Store: device
# [02/10/2021 08:14:48 INFO 139810865182528] Using (gpu(0)) as training context.
# [02/10/2021 08:14:48 INFO 139810865182528] Start training from pretrained model 1.
# [08:14:48] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [08:14:48] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [02/10/2021 08:14:48 INFO 139810865182528] Loaded pretrained model parameters.
#
# 2021-02-10 08:14:52 Training - Training image download completed. Training in progress.[02/10/2021 08:14:57 INFO 139810865182528] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1612944897.793769, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1612944897.79368}
#
# [08:14:58] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [02/10/2021 08:15:08 INFO 139810865182528] Epoch:    0, batches:    100, num_examples:   100, 9.4 samples/sec, epoch time so far:  0:00:10.664518
# [02/10/2021 08:15:14 INFO 139810865182528] Epoch:    0, batches:    200, num_examples:   200, 12.0 samples/sec, epoch time so far:  0:00:16.612068
# [02/10/2021 08:15:20 INFO 139810865182528] Epoch:    0, batches:    300, num_examples:   300, 13.3 samples/sec, epoch time so far:  0:00:22.594300
# [08:15:25] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:15:25 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:15:25 INFO 139810865182528] #quality_metric: host=algo-1, epoch=0, batch=394 train cross_entropy <loss>=(0.769986680853906)
# [02/10/2021 08:15:25 INFO 139810865182528] #quality_metric: host=algo-1, epoch=0, batch=394 train smooth_l1 <loss>=(0.8351059855434613)
# [02/10/2021 08:15:25 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:15:26 INFO 139810865182528] Updated the metrics
# [08:15:39] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:15:39 INFO 139810865182528] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.06155487851488617)
# [02/10/2021 08:15:39 INFO 139810865182528] Updating the best model with validation-mAP=0.06155487851488617
# [02/10/2021 08:15:40 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:15:40 INFO 139810865182528] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1612944940.038076, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1612944897.7942}
#
# [02/10/2021 08:15:46 INFO 139810865182528] Epoch:    1, batches:    100, num_examples:   100, 16.3 samples/sec, epoch time so far:  0:00:06.124403
# [02/10/2021 08:15:52 INFO 139810865182528] Epoch:    1, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.050938
# [02/10/2021 08:15:58 INFO 139810865182528] Epoch:    1, batches:    300, num_examples:   300, 16.7 samples/sec, epoch time so far:  0:00:18.007191
# [08:16:03] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:16:03 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:16:03 INFO 139810865182528] #quality_metric: host=algo-1, epoch=1, batch=394 train cross_entropy <loss>=(0.642466084659561)
# [02/10/2021 08:16:03 INFO 139810865182528] #quality_metric: host=algo-1, epoch=1, batch=394 train smooth_l1 <loss>=(0.7640403969050118)
# [02/10/2021 08:16:03 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:16:03 INFO 139810865182528] Updated the metrics
# [08:16:18] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:16:18 INFO 139810865182528] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.15686659794435787)
# [02/10/2021 08:16:18 INFO 139810865182528] Updating the best model with validation-mAP=0.15686659794435787
# [02/10/2021 08:16:18 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:16:18 INFO 139810865182528] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1612944978.642496, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1612944940.038251}
#
# [02/10/2021 08:16:24 INFO 139810865182528] Epoch:    2, batches:    100, num_examples:   100, 16.4 samples/sec, epoch time so far:  0:00:06.087837
# [02/10/2021 08:16:30 INFO 139810865182528] Epoch:    2, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.048276
# [02/10/2021 08:16:36 INFO 139810865182528] Epoch:    2, batches:    300, num_examples:   300, 16.7 samples/sec, epoch time so far:  0:00:18.010676
# [08:16:42] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:16:42 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:16:42 INFO 139810865182528] #quality_metric: host=algo-1, epoch=2, batch=394 train cross_entropy <loss>=(0.6248440140655621)
# [02/10/2021 08:16:42 INFO 139810865182528] #quality_metric: host=algo-1, epoch=2, batch=394 train smooth_l1 <loss>=(0.6807299214680655)
# [02/10/2021 08:16:42 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:16:42 INFO 139810865182528] Updated the metrics
# [08:16:56] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:16:56 INFO 139810865182528] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.20131683536799905)
# [02/10/2021 08:16:56 INFO 139810865182528] Updating the best model with validation-mAP=0.20131683536799905
# [02/10/2021 08:16:56 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:16:56 INFO 139810865182528] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1612945016.981279, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1612944978.642669}
#
# [02/10/2021 08:17:03 INFO 139810865182528] Epoch:    3, batches:    100, num_examples:   100, 16.0 samples/sec, epoch time so far:  0:00:06.266675
# [02/10/2021 08:17:09 INFO 139810865182528] Epoch:    3, batches:    200, num_examples:   200, 16.2 samples/sec, epoch time so far:  0:00:12.324243
# [02/10/2021 08:17:15 INFO 139810865182528] Epoch:    3, batches:    300, num_examples:   300, 16.4 samples/sec, epoch time so far:  0:00:18.307619
# [08:17:20] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:17:20 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:17:20 INFO 139810865182528] #quality_metric: host=algo-1, epoch=3, batch=394 train cross_entropy <loss>=(0.6100973829993418)
# [02/10/2021 08:17:20 INFO 139810865182528] #quality_metric: host=algo-1, epoch=3, batch=394 train smooth_l1 <loss>=(0.6324596666426983)
# [02/10/2021 08:17:20 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:17:20 INFO 139810865182528] Updated the metrics
# [08:17:36] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:17:36 INFO 139810865182528] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.20209589945696987)
# [02/10/2021 08:17:36 INFO 139810865182528] Updating the best model with validation-mAP=0.20209589945696987
# [02/10/2021 08:17:36 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:17:36 INFO 139810865182528] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1612945056.426855, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1612945016.981557}
#
# [02/10/2021 08:17:42 INFO 139810865182528] Epoch:    4, batches:    100, num_examples:   100, 16.3 samples/sec, epoch time so far:  0:00:06.125730
# [02/10/2021 08:17:48 INFO 139810865182528] Epoch:    4, batches:    200, num_examples:   200, 16.5 samples/sec, epoch time so far:  0:00:12.085571
# [02/10/2021 08:17:54 INFO 139810865182528] Epoch:    4, batches:    300, num_examples:   300, 16.6 samples/sec, epoch time so far:  0:00:18.088986
# [08:18:00] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:18:00 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:18:00 INFO 139810865182528] #quality_metric: host=algo-1, epoch=4, batch=394 train cross_entropy <loss>=(0.609189593334442)
# [02/10/2021 08:18:00 INFO 139810865182528] #quality_metric: host=algo-1, epoch=4, batch=394 train smooth_l1 <loss>=(0.6104280214633042)
# [02/10/2021 08:18:00 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:18:00 INFO 139810865182528] Updated the metrics
# [08:18:14] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:18:14 INFO 139810865182528] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.3404092679074513)
# [02/10/2021 08:18:14 INFO 139810865182528] Updating the best model with validation-mAP=0.3404092679074513
# [02/10/2021 08:18:14 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:18:14 INFO 139810865182528] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1612945094.956226, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1612945056.427035}
#
# [02/10/2021 08:18:21 INFO 139810865182528] Epoch:    5, batches:    100, num_examples:   100, 16.3 samples/sec, epoch time so far:  0:00:06.136643
# [02/10/2021 08:18:27 INFO 139810865182528] Epoch:    5, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.083559
# [02/10/2021 08:18:33 INFO 139810865182528] Epoch:    5, batches:    300, num_examples:   300, 16.6 samples/sec, epoch time so far:  0:00:18.043775
# [08:18:38] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:18:38 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:18:38 INFO 139810865182528] #quality_metric: host=algo-1, epoch=5, batch=394 train cross_entropy <loss>=(0.5865216382577908)
# [02/10/2021 08:18:38 INFO 139810865182528] #quality_metric: host=algo-1, epoch=5, batch=394 train smooth_l1 <loss>=(0.6263991457105863)
# [02/10/2021 08:18:38 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:18:38 INFO 139810865182528] Updated the metrics
# [08:18:53] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:18:53 INFO 139810865182528] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.31675314351749817)
# [02/10/2021 08:18:53 INFO 139810865182528] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1612945133.886673, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1612945094.956903}
#
# [02/10/2021 08:18:59 INFO 139810865182528] Epoch:    6, batches:    100, num_examples:   100, 16.5 samples/sec, epoch time so far:  0:00:06.059103
# [02/10/2021 08:19:06 INFO 139810865182528] Epoch:    6, batches:    200, num_examples:   200, 16.4 samples/sec, epoch time so far:  0:00:12.190739
# [02/10/2021 08:19:12 INFO 139810865182528] Epoch:    6, batches:    300, num_examples:   300, 16.5 samples/sec, epoch time so far:  0:00:18.155606
# [08:19:17] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:19:17 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:19:17 INFO 139810865182528] #quality_metric: host=algo-1, epoch=6, batch=394 train cross_entropy <loss>=(0.5998672326359598)
# [02/10/2021 08:19:17 INFO 139810865182528] #quality_metric: host=algo-1, epoch=6, batch=394 train smooth_l1 <loss>=(0.5440344758589739)
# [02/10/2021 08:19:17 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:19:17 INFO 139810865182528] Updated the metrics
# [08:19:32] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:19:32 INFO 139810865182528] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.3784461922853348)
# [02/10/2021 08:19:32 INFO 139810865182528] Updating the best model with validation-mAP=0.3784461922853348
# [02/10/2021 08:19:32 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:19:32 INFO 139810865182528] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1612945172.4756, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1612945133.886814}
#
# [02/10/2021 08:19:38 INFO 139810865182528] Epoch:    7, batches:    100, num_examples:   100, 16.3 samples/sec, epoch time so far:  0:00:06.129261
# [02/10/2021 08:19:44 INFO 139810865182528] Epoch:    7, batches:    200, num_examples:   200, 16.5 samples/sec, epoch time so far:  0:00:12.108147
# [02/10/2021 08:19:50 INFO 139810865182528] Epoch:    7, batches:    300, num_examples:   300, 16.6 samples/sec, epoch time so far:  0:00:18.051209
# [08:19:56] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:19:56 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:19:56 INFO 139810865182528] #quality_metric: host=algo-1, epoch=7, batch=394 train cross_entropy <loss>=(0.588609982298252)
# [02/10/2021 08:19:56 INFO 139810865182528] #quality_metric: host=algo-1, epoch=7, batch=394 train smooth_l1 <loss>=(0.5155690471299399)
# [02/10/2021 08:19:56 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:19:56 INFO 139810865182528] Updated the metrics
# [08:20:10] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:20:11 INFO 139810865182528] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.3839958207105636)
# [02/10/2021 08:20:11 INFO 139810865182528] Updating the best model with validation-mAP=0.3839958207105636
# [02/10/2021 08:20:11 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:20:11 INFO 139810865182528] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1612945211.247003, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1612945172.475783}
#
# [02/10/2021 08:20:17 INFO 139810865182528] Epoch:    8, batches:    100, num_examples:   100, 16.4 samples/sec, epoch time so far:  0:00:06.097645
# [02/10/2021 08:20:23 INFO 139810865182528] Epoch:    8, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.067617
# [02/10/2021 08:20:29 INFO 139810865182528] Epoch:    8, batches:    300, num_examples:   300, 16.6 samples/sec, epoch time so far:  0:00:18.041231
# [08:20:34] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:20:34 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:20:34 INFO 139810865182528] #quality_metric: host=algo-1, epoch=8, batch=394 train cross_entropy <loss>=(0.5789953933197549)
# [02/10/2021 08:20:34 INFO 139810865182528] #quality_metric: host=algo-1, epoch=8, batch=394 train smooth_l1 <loss>=(0.48219503347757814)
# [02/10/2021 08:20:34 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:20:35 INFO 139810865182528] Updated the metrics
# [08:20:50] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:20:50 INFO 139810865182528] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.42211109012845355)
# [02/10/2021 08:20:50 INFO 139810865182528] Updating the best model with validation-mAP=0.42211109012845355
# [02/10/2021 08:20:50 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:20:50 INFO 139810865182528] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1612945250.79587, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1612945211.247182}
#
# [02/10/2021 08:20:56 INFO 139810865182528] Epoch:    9, batches:    100, num_examples:   100, 16.3 samples/sec, epoch time so far:  0:00:06.136121
# [02/10/2021 08:21:02 INFO 139810865182528] Epoch:    9, batches:    200, num_examples:   200, 16.5 samples/sec, epoch time so far:  0:00:12.116941
# [02/10/2021 08:21:08 INFO 139810865182528] Epoch:    9, batches:    300, num_examples:   300, 16.5 samples/sec, epoch time so far:  0:00:18.165678
# [08:21:14] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:21:14 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:21:14 INFO 139810865182528] #quality_metric: host=algo-1, epoch=9, batch=394 train cross_entropy <loss>=(0.5512879806440234)
# [02/10/2021 08:21:14 INFO 139810865182528] #quality_metric: host=algo-1, epoch=9, batch=394 train smooth_l1 <loss>=(0.4733926731823147)
# [02/10/2021 08:21:14 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:21:14 INFO 139810865182528] Updated the metrics
# [08:21:30] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:21:30 INFO 139810865182528] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.34482182095947805)
# [02/10/2021 08:21:30 INFO 139810865182528] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1612945290.403841, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1612945250.796047}
#
# [02/10/2021 08:21:36 INFO 139810865182528] Epoch:    10, batches:    100, num_examples:   100, 16.4 samples/sec, epoch time so far:  0:00:06.113646
# [02/10/2021 08:21:42 INFO 139810865182528] Epoch:    10, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.052008
# [02/10/2021 08:21:48 INFO 139810865182528] Epoch:    10, batches:    300, num_examples:   300, 16.7 samples/sec, epoch time so far:  0:00:17.987775
# [08:21:53] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:21:53 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:21:53 INFO 139810865182528] #quality_metric: host=algo-1, epoch=10, batch=394 train cross_entropy <loss>=(0.5729028708985838)
# [02/10/2021 08:21:53 INFO 139810865182528] #quality_metric: host=algo-1, epoch=10, batch=394 train smooth_l1 <loss>=(0.4460542490402601)
# [02/10/2021 08:21:53 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:21:54 INFO 139810865182528] Updated the metrics
# [08:22:09] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:22:09 INFO 139810865182528] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.46549916447743167)
# [02/10/2021 08:22:09 INFO 139810865182528] Updating the best model with validation-mAP=0.46549916447743167
# [02/10/2021 08:22:09 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:22:09 INFO 139810865182528] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1612945329.439119, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1612945290.403978}
#
# [02/10/2021 08:22:15 INFO 139810865182528] Epoch:    11, batches:    100, num_examples:   100, 16.2 samples/sec, epoch time so far:  0:00:06.182456
# [02/10/2021 08:22:21 INFO 139810865182528] Epoch:    11, batches:    200, num_examples:   200, 16.5 samples/sec, epoch time so far:  0:00:12.157806
# [02/10/2021 08:22:27 INFO 139810865182528] Epoch:    11, batches:    300, num_examples:   300, 16.5 samples/sec, epoch time so far:  0:00:18.143796
# [08:22:33] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:22:33 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:22:33 INFO 139810865182528] #quality_metric: host=algo-1, epoch=11, batch=394 train cross_entropy <loss>=(0.5706554344061777)
# [02/10/2021 08:22:33 INFO 139810865182528] #quality_metric: host=algo-1, epoch=11, batch=394 train smooth_l1 <loss>=(0.43278596233278777)
# [02/10/2021 08:22:33 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:22:33 INFO 139810865182528] Updated the metrics
# [08:22:48] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:22:48 INFO 139810865182528] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.4562560856736413)
# [02/10/2021 08:22:48 INFO 139810865182528] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1612945368.368791, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1612945329.439277}
#
# [02/10/2021 08:22:54 INFO 139810865182528] Epoch:    12, batches:    100, num_examples:   100, 16.3 samples/sec, epoch time so far:  0:00:06.133174
# [02/10/2021 08:23:00 INFO 139810865182528] Epoch:    12, batches:    200, num_examples:   200, 16.5 samples/sec, epoch time so far:  0:00:12.103027
# [02/10/2021 08:23:06 INFO 139810865182528] Epoch:    12, batches:    300, num_examples:   300, 16.4 samples/sec, epoch time so far:  0:00:18.288853
# [08:23:12] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:23:12 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:23:12 INFO 139810865182528] #quality_metric: host=algo-1, epoch=12, batch=394 train cross_entropy <loss>=(0.5503582712484256)
# [02/10/2021 08:23:12 INFO 139810865182528] #quality_metric: host=algo-1, epoch=12, batch=394 train smooth_l1 <loss>=(0.42522261423617363)
# [02/10/2021 08:23:12 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:23:12 INFO 139810865182528] Updated the metrics
# [08:23:27] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:23:28 INFO 139810865182528] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.3962631098637942)
# [02/10/2021 08:23:28 INFO 139810865182528] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1612945408.215508, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1612945368.368926}
#
# [02/10/2021 08:23:34 INFO 139810865182528] Epoch:    13, batches:    100, num_examples:   100, 16.4 samples/sec, epoch time so far:  0:00:06.100626
# [02/10/2021 08:23:40 INFO 139810865182528] Epoch:    13, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.073581
# [02/10/2021 08:23:46 INFO 139810865182528] Epoch:    13, batches:    300, num_examples:   300, 16.6 samples/sec, epoch time so far:  0:00:18.032215
# [08:23:51] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:23:51 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:23:51 INFO 139810865182528] #quality_metric: host=algo-1, epoch=13, batch=394 train cross_entropy <loss>=(0.5337943332944131)
# [02/10/2021 08:23:51 INFO 139810865182528] #quality_metric: host=algo-1, epoch=13, batch=394 train smooth_l1 <loss>=(0.4260593608206421)
# [02/10/2021 08:23:51 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:23:51 INFO 139810865182528] Updated the metrics
# [08:24:07] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:24:08 INFO 139810865182528] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.46589213815182245)
# [02/10/2021 08:24:08 INFO 139810865182528] Updating the best model with validation-mAP=0.46589213815182245
# [02/10/2021 08:24:08 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:24:08 INFO 139810865182528] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1612945448.403997, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1612945408.215645}
#
# [02/10/2021 08:24:14 INFO 139810865182528] Epoch:    14, batches:    100, num_examples:   100, 16.4 samples/sec, epoch time so far:  0:00:06.096717
# [02/10/2021 08:24:20 INFO 139810865182528] Epoch:    14, batches:    200, num_examples:   200, 16.6 samples/sec, epoch time so far:  0:00:12.071596
# [02/10/2021 08:24:26 INFO 139810865182528] Epoch:    14, batches:    300, num_examples:   300, 16.7 samples/sec, epoch time so far:  0:00:18.016229
# [08:24:32] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:24:32 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:24:32 INFO 139810865182528] #quality_metric: host=algo-1, epoch=14, batch=394 train cross_entropy <loss>=(0.552960688141004)
# [02/10/2021 08:24:32 INFO 139810865182528] #quality_metric: host=algo-1, epoch=14, batch=394 train smooth_l1 <loss>=(0.3999107802135587)
# [02/10/2021 08:24:32 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:24:32 INFO 139810865182528] Updated the metrics
# ...
# [08:47:48] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:47:49 INFO 139810865182528] #quality_metric: host=algo-1, epoch=49, validation mAP <score>=(0.37324651979467993)
# [02/10/2021 08:47:49 INFO 139810865182528] #progress_metric: host=algo-1, completed 50 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 50, "sum": 50.0, "min": 50}}, "EndTime": 1612946869.016755, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 49}, "StartTime": 1612946829.953838}
#
# [02/10/2021 08:47:55 INFO 139810865182528] Epoch:    50, batches:    100, num_examples:   100, 16.6 samples/sec, epoch time so far:  0:00:06.038036
# [02/10/2021 08:48:00 INFO 139810865182528] Epoch:    50, batches:    200, num_examples:   200, 16.8 samples/sec, epoch time so far:  0:00:11.931724
# [02/10/2021 08:48:06 INFO 139810865182528] Epoch:    50, batches:    300, num_examples:   300, 16.7 samples/sec, epoch time so far:  0:00:17.962474
# [08:48:12] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:48:12 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:48:12 INFO 139810865182528] #quality_metric: host=algo-1, epoch=50, batch=394 train cross_entropy <loss>=(0.4489753655545985)
# [02/10/2021 08:48:12 INFO 139810865182528] #quality_metric: host=algo-1, epoch=50, batch=394 train smooth_l1 <loss>=(0.32262802009276464)
# [02/10/2021 08:48:12 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:48:12 INFO 139810865182528] Updated the metrics
# [08:48:28] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:48:28 INFO 139810865182528] #quality_metric: host=algo-1, epoch=50, validation mAP <score>=(0.5198322485821245)
# [02/10/2021 08:48:28 INFO 139810865182528] Updating the best model with validation-mAP=0.5198322485821245
# [02/10/2021 08:48:28 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:48:28 INFO 139810865182528] #progress_metric: host=algo-1, completed 51 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 51, "sum": 51.0, "min": 51}}, "EndTime": 1612946908.797695, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 50}, "StartTime": 1612946869.01689}
#
# [02/10/2021 08:48:34 INFO 139810865182528] Epoch:    51, batches:    100, num_examples:   100, 16.8 samples/sec, epoch time so far:  0:00:05.954090
# [02/10/2021 08:48:40 INFO 139810865182528] Epoch:    51, batches:    200, num_examples:   200, 16.9 samples/sec, epoch time so far:  0:00:11.823877
# [02/10/2021 08:48:46 INFO 139810865182528] Epoch:    51, batches:    300, num_examples:   300, 16.9 samples/sec, epoch time so far:  0:00:17.705229
# [08:48:52] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:48:52 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:48:52 INFO 139810865182528] #quality_metric: host=algo-1, epoch=51, batch=394 train cross_entropy <loss>=(0.4583936314220014)
# [02/10/2021 08:48:52 INFO 139810865182528] #quality_metric: host=algo-1, epoch=51, batch=394 train smooth_l1 <loss>=(0.281513746875363)
# [02/10/2021 08:48:52 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:48:52 INFO 139810865182528] Updated the metrics
# [08:49:07] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:49:08 INFO 139810865182528] #quality_metric: host=algo-1, epoch=51, validation mAP <score>=(0.5169224912313657)
# [02/10/2021 08:49:08 INFO 139810865182528] #progress_metric: host=algo-1, completed 52 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 52, "sum": 52.0, "min": 52}}, "EndTime": 1612946948.322788, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 51}, "StartTime": 1612946908.79788}
#
# [02/10/2021 08:49:14 INFO 139810865182528] Epoch:    52, batches:    100, num_examples:   100, 16.6 samples/sec, epoch time so far:  0:00:06.033680
# [02/10/2021 08:49:20 INFO 139810865182528] Epoch:    52, batches:    200, num_examples:   200, 16.9 samples/sec, epoch time so far:  0:00:11.854201
# [02/10/2021 08:49:25 INFO 139810865182528] Epoch:    52, batches:    300, num_examples:   300, 17.1 samples/sec, epoch time so far:  0:00:17.581433
# [08:49:31] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:49:31 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:49:31 INFO 139810865182528] #quality_metric: host=algo-1, epoch=52, batch=394 train cross_entropy <loss>=(0.46253875136704736)
# [02/10/2021 08:49:31 INFO 139810865182528] #quality_metric: host=algo-1, epoch=52, batch=394 train smooth_l1 <loss>=(0.2941197742072853)
# [02/10/2021 08:49:31 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:49:31 INFO 139810865182528] Updated the metrics
# [08:49:46] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:49:46 INFO 139810865182528] #quality_metric: host=algo-1, epoch=52, validation mAP <score>=(0.4972459072236812)
# [02/10/2021 08:49:46 INFO 139810865182528] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 53, "sum": 53.0, "min": 53}}, "EndTime": 1612946986.913448, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 52}, "StartTime": 1612946948.32296}
#
# [02/10/2021 08:49:52 INFO 139810865182528] Epoch:    53, batches:    100, num_examples:   100, 16.8 samples/sec, epoch time so far:  0:00:05.960225
# [02/10/2021 08:49:58 INFO 139810865182528] Epoch:    53, batches:    200, num_examples:   200, 16.9 samples/sec, epoch time so far:  0:00:11.862443
# [02/10/2021 08:50:04 INFO 139810865182528] Epoch:    53, batches:    300, num_examples:   300, 16.9 samples/sec, epoch time so far:  0:00:17.778937
# [08:50:10] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:50:10 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:50:10 INFO 139810865182528] #quality_metric: host=algo-1, epoch=53, batch=394 train cross_entropy <loss>=(0.47009939946459267)
# [02/10/2021 08:50:10 INFO 139810865182528] #quality_metric: host=algo-1, epoch=53, batch=394 train smooth_l1 <loss>=(0.2820732189997542)
# [02/10/2021 08:50:10 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:50:10 INFO 139810865182528] Updated the metrics
# [08:50:25] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:50:26 INFO 139810865182528] #quality_metric: host=algo-1, epoch=53, validation mAP <score>=(0.487188866091011)
# [02/10/2021 08:50:26 INFO 139810865182528] #progress_metric: host=algo-1, completed 54 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 54, "sum": 54.0, "min": 54}}, "EndTime": 1612947026.163297, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 53}, "StartTime": 1612946986.913613}
#
# [02/10/2021 08:50:32 INFO 139810865182528] Epoch:    54, batches:    100, num_examples:   100, 16.8 samples/sec, epoch time so far:  0:00:05.963477
# [02/10/2021 08:50:38 INFO 139810865182528] Epoch:    54, batches:    200, num_examples:   200, 16.9 samples/sec, epoch time so far:  0:00:11.847738
# [02/10/2021 08:50:43 INFO 139810865182528] Epoch:    54, batches:    300, num_examples:   300, 16.9 samples/sec, epoch time so far:  0:00:17.723636
# [08:50:49] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:50:49 WARNING 139810865182528] The number of batches processed (394) is less than expected (at least 400). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [02/10/2021 08:50:49 INFO 139810865182528] #quality_metric: host=algo-1, epoch=54, batch=394 train cross_entropy <loss>=(0.44569622682385834)
# [02/10/2021 08:50:49 INFO 139810865182528] #quality_metric: host=algo-1, epoch=54, batch=394 train smooth_l1 <loss>=(0.26862709474108976)
# [02/10/2021 08:50:49 INFO 139810865182528] Round of batches complete
# [02/10/2021 08:50:49 INFO 139810865182528] Updated the metrics
#
# 2021-02-10 08:51:07 Uploading - Uploading generated training model[08:51:05] /opt/brazil-pkg-cache/packages/AIApplicationsPipeIterators/AIApplicationsPipeIterators-1.0.1174.0/AL2012/generic-flavor/src/data_iter/src/ease_det_image_iter.cpp:88: No more data read from PIPE, reaching end of PIPE
# [02/10/2021 08:51:05 INFO 139810865182528] #quality_metric: host=algo-1, epoch=54, validation mAP <score>=(0.5008737651786936)
# [02/10/2021 08:51:05 INFO 139810865182528] Early stop condition met. Stopping training.
# [02/10/2021 08:51:05 INFO 139810865182528] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 55, "sum": 55.0, "min": 55}}, "EndTime": 1612947065.545525, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 54}, "StartTime": 1612947026.163488}
#
# [02/10/2021 08:51:05 WARNING 139810865182528] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/10/2021 08:51:05 INFO 139810865182528] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [02/10/2021 08:51:05 INFO 139810865182528] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "totaltime": {"count": 1, "max": 2178081.388235092, "sum": 2178081.388235092, "min": 2178081.388235092}, "setuptime": {"count": 1, "max": 11.079072952270508, "sum": 11.079072952270508, "min": 11.079072952270508}}, "EndTime": 1612947065.680192, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1612944887.711474}
#
#
# 2021-02-10 08:51:40 Completed - Training job completed
# ProfilerReport-1612944635: IssuesFound
# Training seconds: 2279
# Billable seconds: 2279
# CPU times: user 5.9 s, sys: 196 ms, total: 6.09 s
# Wall time: 41min 15s

# %%
import boto3
client = boto3.client('sagemaker')

##### REPLACE WITH YOUR OWN TRAINING JOB NAME
# In the above console screenshots the job name was 'bees-detection-resnet'.
# But if you used Python to kick off the training job,
# then 'training_job_name' is already set, so you can comment out the line below.
#training_job_name = 'bees-detection-resnet'
training_job_name = 'bees-detection-resnet2'
##### REPLACE WITH YOUR OWN TRAINING JOB NAME

training_info = client.describe_training_job(TrainingJobName='object-detection-2021-02-10-08-10-35-992')

print("Training job status: ", training_info['TrainingJobStatus'])
print("Secondary status: ", training_info['SecondaryStatus'])
# Out:
# Training job status:  Completed
# Secondary status:  Completed

# %%
import time
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
model_name = training_job_name + '-model' + timestamp

training_image = training_info['AlgorithmSpecification']['TrainingImage']
model_data = training_info['ModelArtifacts']['S3ModelArtifacts']

primary_container = {
    'Image': training_image,
    'ModelDataUrl': model_data,
}

from sagemaker import get_execution_role

role = get_execution_role()

create_model_response = client.create_model(
    ModelName = model_name,
    ExecutionRoleArn = role,
    PrimaryContainer = primary_container)

print(create_model_response['ModelArn'])
# Out:
# arn:aws:sagemaker:us-east-1:165417668877:model/bees-detection-resnet2-model-2021-02-10-08-54-59

# %%
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_config_name = 'object-detection-2021-02-10-08-10-35-992' + '-epc'
endpoint_config_response = client.create_endpoint_config(
    EndpointConfigName = endpoint_config_name,
    ProductionVariants=[{
        'InstanceType':'ml.t2.medium',
        'InitialInstanceCount':1,
        'ModelName':model_name,
        'VariantName':'AllTraffic'}])

print('Endpoint configuration name: {}'.format(endpoint_config_name))
print('Endpoint configuration arn:  {}'.format(endpoint_config_response['EndpointConfigArn']))
# Out:
# Endpoint configuration name: object-detection-2021-02-10-08-10-35-992-epc
# Endpoint configuration arn:  arn:aws:sagemaker:us-east-1:165417668877:endpoint-config/object-detection-2021-02-10-08-10-35-992-epc

# %% [markdown]
# # Create Endpoint

# %%
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_name = 'object-detection-2021-02-10-08-10-35-992' + '-ep'
print('Endpoint name: {}'.format(endpoint_name))

endpoint_params = {
    'EndpointName': endpoint_name,
    'EndpointConfigName': endpoint_config_name,
}
endpoint_response = client.create_endpoint(**endpoint_params)
print('EndpointArn = {}'.format(endpoint_response['EndpointArn']))

# get the status of the endpoint
response = client.describe_endpoint(EndpointName=endpoint_name)
status = response['EndpointStatus']
print('EndpointStatus = {}'.format(status))
# Out:
# Endpoint name: object-detection-2021-02-10-08-10-35-992-ep
# EndpointArn = arn:aws:sagemaker:us-east-1:165417668877:endpoint/object-detection-2021-02-10-08-10-35-992-ep
# EndpointStatus = Creating

# %% [markdown]
# # Perform inference

# %%
import glob
test_images = glob.glob('test/*')
print(*test_images, sep="\n")
# Out:
# test/22544384.jpg
# test/22971237.jpg
# test/23086755.jpg
# test/22741822.jpg
# test/22774999.jpg
# test/22673445.jpg
# test/22469656.jpg
# test/22901964.jpg
# test/22775000.jpg
# test/22427594.jpg

# %%
def prediction_to_bbox_data(image_path, prediction):
    class_id, confidence, xmin, ymin, xmax, ymax = prediction
    width, height = Image.open(image_path).size
    bbox_data = {'class_id': class_id,
               'height': (ymax-ymin)*height,
               'width': (xmax-xmin)*width,
               'left': xmin*width,
               'top': ymin*height}
    return bbox_data

# %%
import matplotlib.pyplot as plt

endpoint_name='object-detection-2021-02-10-08-10-35-992' + '-ep'

runtime_client = boto3.client('sagemaker-runtime')

# Call SageMaker endpoint to obtain predictions
def get_predictions_for_img(runtime_client, endpoint_name, img_path):
    with open(img_path, 'rb') as f:
        payload = f.read()
        payload = bytearray(payload)

    response = runtime_client.invoke_endpoint(EndpointName=endpoint_name, 
                                       ContentType='application/x-image', 
                                       Body=payload)

    result = response['Body'].read()
    result = json.loads(result)
    return result


# wait until the status has changed
client.get_waiter('endpoint_in_service').wait(EndpointName=endpoint_name)
endpoint_response = client.describe_endpoint(EndpointName=endpoint_name)
status = endpoint_response['EndpointStatus']
if status != 'InService':
    raise Exception('Endpoint creation failed.')

for test_image in test_images:
    result = get_predictions_for_img(runtime_client, endpoint_name, test_image)
    confidence_threshold = .5
    best_n = 1
    # display the best n predictions with confidence > confidence_threshold
    predictions = [prediction for prediction in result['prediction'] if prediction[1] > confidence_threshold]
    predictions.sort(reverse=True, key = lambda x: x[1])
    bboxes = [prediction_to_bbox_data(test_image, prediction) for prediction in predictions[:best_n]]
    show_annotated_image(test_image, bboxes)

# %% [markdown]
# # Cleanup

# %%
client.delete_endpoint(EndpointName=endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '2e3f7f4c-b717-4802-afb7-d569c7b8d118',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '2e3f7f4c-b717-4802-afb7-d569c7b8d118',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Wed, 10 Feb 2021 09:14:25 GMT'},
#   'RetryAttempts': 0}}
