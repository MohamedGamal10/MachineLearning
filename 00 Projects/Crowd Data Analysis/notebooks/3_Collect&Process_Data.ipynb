# %%
# Setup Libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff
from datetime import datetime, timedelta
import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
# Setup Dataset Path
DATA_RSRP_PATH = '../data/processed/RSRP_processed.parquet'
DATA_TRAFFIC_PATH = '../data/processed/TrafficVolume_processed.parquet'

# %%
#Load Data
df_rsrp = pd.read_parquet(DATA_RSRP_PATH)
df_traffic = pd.read_parquet(DATA_TRAFFIC_PATH)

# %% [markdown]
# ### We will Choose data that related to Operator A from two above Dataset then join two dataset

# %%
#Select Rows that related to Operator A from all Dataset
df_rsrp_operator_a = df_rsrp[df_rsrp['RadioOperatorName']=='Operator A']
df_traffic_operator_a = df_traffic[df_traffic['RadioOperatorName']=='Operator A']

# %%
print(df_rsrp_operator_a.shape)
print(df_traffic_operator_a.shape)
# Out:
# (1406266, 11)
# (68171, 10)

# %%
#drop columns that not used in traffic dataset
df_traffic_operator_a = df_traffic_operator_a.drop(['RadioConnectionType', 'Country', 'RadioNetworkGeneration', 'RadioOperatorName','RadioMobileDataEnabled'], axis=1)

# %%
#Select rows from RSRP Dataset where location founded in traffic volume Dataset
df_traffic_operator_a['conc'] = df_traffic_operator_a['LocationLatitude'].map(str) + ' - '+df_traffic_operator_a['LocationLongitude'].map(str)
df_rsrp_operator_a['conc'] = df_rsrp_operator_a['LocationLatitude'].map(str) + ' - '+df_rsrp_operator_a['LocationLongitude'].map(str)
df_join_rsrp_location = df_rsrp_operator_a[df_rsrp_operator_a['conc'].isin(df_traffic_operator_a['conc'].unique())]

# %%
df_join_rsrp_location.head(1)
# Out:
#              Timestamp  LocationLatitude  LocationLongitude  \
# 62 2019-11-02 01:39:40         24.691517           46.65258
#
#    RadioConnectionType       Country RadioNetworkGeneration RadioOperatorName  \
# 62              Mobile  Saudi Arabia                     4G        Operator A
#
#     RSRP RadioMobileDataEnabled DeviceManufacturer      DeviceName  \
# 62   -94                Enabled             HUAWEI  Huawei Y5 2019
#
#                     conc
# 62  24.691517 - 46.65258

# %%
df_traffic_operator_a.head(1)
# Out:
#             Timestamp  LocationLatitude  LocationLongitude TrafficDirection  \
# 0 2019-11-02 00:45:00         24.636574          46.710026         Downlink
#
#    TrafficVolume                   conc
# 0       14.95763  24.636574 - 46.710026

# %%
# Round Time Function
def round_time(dt=None, round_to=60*15):
    if dt == None: 
        dt = datetime.datetime.now()
    seconds = (dt - dt.min).seconds
    rounding = (seconds+round_to/2) // round_to * round_to
    return dt + datetime.timedelta(0,rounding-seconds,-dt.microsecond)

# %%
#Select rows based on time approxmate
df_join_rsrp_location['time_approxmate'] = df_join_rsrp_location['Timestamp'].apply(lambda x : round_time(x.to_pydatetime()))
df_traffic_operator_a['time_approxmate'] = df_traffic_operator_a['Timestamp']

# %%
df_join_rsrp_location.head(1)
# Out:
#              Timestamp  LocationLatitude  LocationLongitude  \
# 62 2019-11-02 01:39:40         24.691517           46.65258
#
#    RadioConnectionType       Country RadioNetworkGeneration RadioOperatorName  \
# 62              Mobile  Saudi Arabia                     4G        Operator A
#
#     RSRP RadioMobileDataEnabled DeviceManufacturer      DeviceName  \
# 62   -94                Enabled             HUAWEI  Huawei Y5 2019
#
#                     conc     time_approxmate
# 62  24.691517 - 46.65258 2019-11-02 01:45:00

# %%
df_traffic_operator_a.head(1)
# Out:
#             Timestamp  LocationLatitude  LocationLongitude TrafficDirection  \
# 0 2019-11-02 00:45:00         24.636574          46.710026         Downlink
#
#    TrafficVolume                   conc     time_approxmate
# 0       14.95763  24.636574 - 46.710026 2019-11-02 00:45:00

# %%
# Calculate mean value of RSRP for each timestamp
df_join_rsrp_location['conctime'] = df_join_rsrp_location['conc'].map(str) + ' - ' + df_join_rsrp_location['time_approxmate'].map(str)
snap_mean = df_join_rsrp_location[['conctime','RSRP']]
snap_mean = snap_mean.groupby('conctime').mean().reset_index()

# %%
# Add mean value of rsrp to df_join_rsrp_location
df_join_rsrp_location = pd.merge(df_join_rsrp_location,snap_mean, on=['conctime'])
df_join_rsrp_location.head(1)
# Out:
#             Timestamp  LocationLatitude  LocationLongitude  \
# 0 2019-11-02 01:39:40         24.691517           46.65258
#
#   RadioConnectionType       Country RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile  Saudi Arabia                     4G        Operator A
#
#    RSRP_x RadioMobileDataEnabled DeviceManufacturer      DeviceName  \
# 0     -94                Enabled             HUAWEI  Huawei Y5 2019
#
#                    conc     time_approxmate  \
# 0  24.691517 - 46.65258 2019-11-02 01:45:00
#
#                                      conctime     RSRP_y
# 0  24.691517 - 46.65258 - 2019-11-02 01:45:00 -93.444444

# %%
result = pd.merge(df_join_rsrp_location, df_traffic_operator_a, on=["conc",'time_approxmate'])
result.head(1)
# Out:
#           Timestamp_x  LocationLatitude_x  LocationLongitude_x  \
# 0 2019-11-02 01:39:40           24.691517             46.65258
#
#   RadioConnectionType       Country RadioNetworkGeneration RadioOperatorName  \
# 0              Mobile  Saudi Arabia                     4G        Operator A
#
#    RSRP_x RadioMobileDataEnabled DeviceManufacturer      DeviceName  \
# 0     -94                Enabled             HUAWEI  Huawei Y5 2019
#
#                    conc     time_approxmate  \
# 0  24.691517 - 46.65258 2019-11-02 01:45:00
#
#                                      conctime     RSRP_y         Timestamp_y  \
# 0  24.691517 - 46.65258 - 2019-11-02 01:45:00 -93.444444 2019-11-02 01:45:00
#
#    LocationLatitude_y  LocationLongitude_y TrafficDirection  TrafficVolume
# 0           24.691517             46.65258         Downlink       6.218721

# %%
#Drop unneeded columns
result.drop(['conc','conctime','Timestamp_y','LocationLatitude_y',
             'LocationLongitude_y','Country','RadioOperatorName'],axis=1,inplace=True)
result.head(1)
# Out:
#           Timestamp_x  LocationLatitude_x  LocationLongitude_x  \
# 0 2019-11-02 01:39:40           24.691517             46.65258
#
#   RadioConnectionType RadioNetworkGeneration  RSRP_x RadioMobileDataEnabled  \
# 0              Mobile                     4G     -94                Enabled
#
#   DeviceManufacturer      DeviceName     time_approxmate     RSRP_y  \
# 0             HUAWEI  Huawei Y5 2019 2019-11-02 01:45:00 -93.444444
#
#   TrafficDirection  TrafficVolume
# 0         Downlink       6.218721

# %%
#Rename some columns
result.rename(columns ={'Timestamp_x':'Timestamp','LocationLatitude_x':'LocationLatitude',
                        'LocationLongitude_x':'LocationLongitude','RSRP_y':'Average_RSRP','RSRP_x':'RSRP'},inplace=True)
result.head(1)
# Out:
#             Timestamp  LocationLatitude  LocationLongitude  \
# 0 2019-11-02 01:39:40         24.691517           46.65258
#
#   RadioConnectionType RadioNetworkGeneration  RSRP RadioMobileDataEnabled  \
# 0              Mobile                     4G   -94                Enabled
#
#   DeviceManufacturer      DeviceName     time_approxmate  Average_RSRP  \
# 0             HUAWEI  Huawei Y5 2019 2019-11-02 01:45:00    -93.444444
#
#   TrafficDirection  TrafficVolume
# 0         Downlink       6.218721

# %%
# Show uniqe values of each column
for i in range(result.shape[1]):
    print("###########################     {}    ###########################".format(result.columns[i]))
    print(result.iloc[:,i].unique())
    print(" ")
    print(" ")
# Out:
# ###########################     Timestamp    ###########################
# ['2019-11-02T01:39:40.000000000' '2019-11-02T01:41:59.000000000'
#  '2019-11-02T01:41:54.000000000' ... '2019-11-04T19:27:52.000000000'
#  '2019-11-04T19:28:57.000000000' '2019-11-03T08:05:32.000000000']
#
#
# ###########################     LocationLatitude    ###########################
# [24.691517 24.618221 24.751925 ... 24.523375 24.812092 24.814854]
#
#
# ###########################     LocationLongitude    ###########################
# [46.65258  46.72937  46.8578   ... 46.752865 46.753765 46.752903]
#
#
# ###########################     RadioConnectionType    ###########################
# ['Mobile' 'WiFi' 'Unknown']
#
#
# ###########################     RadioNetworkGeneration    ###########################
# ['4G' '3G' '2G']
#
#
# ###########################     RSRP    ###########################
# [ -94  -89  -95  -91  -93  -97 -140  -79  -87  -96  -78 -100  -83  -92
#   -98  -72  -81  -86  -82  -63  -85  -68  -67  -80  -90  -88  -99  -76
#  -105 -108 -102 -104  -70  -69  -74  -66 -119 -120 -118 -121 -129 -126
#  -112 -117 -111 -114 -103 -115 -116 -113  -84 -101  -73  -77  -75  -54
#   -65  -71  -64  -61  -62 -107 -106 -110 -109 -124 -123  -60  -59 -122
#  -125  -58  -53  -56 -127 -132  -55  -52  -57 -130  -49  -45  -50 -128
#   -51]
#
#
# ###########################     RadioMobileDataEnabled    ###########################
# ['Enabled' 'Disabled']
#
#
# ###########################     DeviceManufacturer    ###########################
# ['HUAWEI' 'HTC' 'samsung' 'HMD Global' 'Realme' 'LGE' 'OnePlus' 'Sony'
#  'OPPO' 'vivo' 'LENOVO' 'TCL' 'htc' 'Xiaomi' 'lenovo' 'motorola'
#  'PANASONIC' 'Lenovo' 'E1']
#
#
# ###########################     DeviceName    ###########################
# ['Huawei Y5 2019' 'Desire 10 Lifestyle' 'Galaxy On7 Prime' 'Galaxy A30S'
#  'Nokia 7 Plus' 'Nokia 6' 'Galaxy A20S' 'Galaxy Note4' 'Galaxy Note3'
#  'Galaxy J7 Neo' 'Galaxy A7 (2018)' 'Galaxy A7(2017)' 'Galaxy J7 Prime'
#  'Galaxy On Nxt' 'Realme X青春版' 'Realme 3Pro' 'Galaxy Note9'
#  'Huawei Y9 2019' 'Mate 8' 'Galaxy S10+' 'Nokia 2.2' 'Lg K10 Lte'
#  'Honor 10 Lite' 'Galaxy S5' 'Galaxy S6 Edge+' 'Galaxy A20' 'Oneplus6T'
#  'Huawei Y7 2018' 'Huawei Y7 Prime 2018' 'Galaxy Note8' 'Xperia L1'
#  'Galaxy S8' 'Galaxy J6+' 'Galaxy J7' 'Y7' 'Galaxy A51' 'Galaxy A70'
#  'Galaxy Grand2' 'D728W' 'Desire 728 Dual Sim' 'Galaxy S7 Edge'
#  'Galaxy S9+' 'Realme 2 Pro' 'Galaxy A10' 'Vivo 1806' 'Vivo 1611'
#  'Galaxy A50' 'Desire 12' 'Desire 628 Dual Sim' 'Htc Desire 628 Dual Sim'
#  'Galaxy S6 Edge' 'Galaxy S8+' 'Huawei P30 Lite' 'Honor 10I'
#  'Vibe K6 Note' 'Desire 830 Dual Sim' 'Galaxy J7(2016)' 'Galaxy A10S'
#  'Lg G4' 'Galaxy S9' 'Galaxy J4' 'Galaxy Grand Prime Pro' 'Galaxy J2'
#  'Galaxy J2 Pro' 'Alcatel 3X' 'Htc U11+' 'Nokia 5' 'Galaxy A9 (2018)'
#  'Galaxy J4+' 'Galaxy Note Fan Edition' 'Galaxy A5' 'S90-A' 'Desire 12+'
#  'Galaxy J5 Prime' 'Huawei P Smart Pro' 'Huawei Y9 Prime 2019'
#  'Huawei Y9S' 'Y9 Prime 2019' 'Galaxy A5(2017)' 'Huawei Nova 3I' 'Nova 3I'
#  'Honor 8X' 'Mi A2 Lite' 'P8 Lite' 'Galaxy Note5' 'Pocofone F1'
#  'Oneplus5T' 'Galaxy A8(2018)' 'Galaxy S7' 'Galaxy A30' 'Galaxy J6'
#  'Huawei Mate 20 Pro' 'Mate 20 Pro' 'Lenovo K8 Note' 'Nokia 8'
#  'Redmi 5 Plus' 'Xperia Xa1 Ultra' 'Galaxy J8' 'Galaxy Grand Prime Plus'
#  'Moto G (5S) Plus' 'Honor View20' 'Alcatel 1X' 'Xperia Z2' 'Galaxy A6+'
#  'Eluga A4' 'Xperia Xa1' 'Honor 9A' 'Huawei Y7 2019' 'Huawei Y7S'
#  'Y7 Prime 2019' 'Huawei P30' 'P20 Pro' 'P20Pro' 'Lg X Power'
#  'Redmi Note 5 Pro' 'Galaxy Note10+' 'F11 Pro' 'Galaxy Note Edge' 'F7'
#  'Huawei P Smart' 'Z6' 'Z6 Pro' 'Mi 9T' 'Redmi K20' 'E1' 'U12+' 'Reno2 Z'
#  'Honor 8S' 'Nokia 3' 'Redmi Note 8 Pro' 'Galaxy C9 Pro'
#  'Galaxy A8+(2018)' 'Galaxy J3(2017)' 'Galaxy S4' 'Mate 10 Lite'
#  'Redmi Note 7' 'Galaxy J2 Prime' 'Eluga Mark 2' 'Desire 10 Pro'
#  'Mate 10 Pro' 'Galaxy Grand Prime' 'Redmi 6A' 'Redmi Note 8'
#  'Huawei Y6 2019' 'Xperia Xz2' 'Galaxy J3(2016)' 'U11' 'Nokia 5.1 Plus'
#  'Galaxy Grand Neo Plus' 'Galaxy S5 Dual Sim' 'Motorola One Vision'
#  'Nokia 6.1 Plus' 'Oneplus 7']
#
#
# ###########################     time_approxmate    ###########################
# ['2019-11-02T01:45:00.000000000' '2019-11-02T01:00:00.000000000'
#  '2019-11-02T09:00:00.000000000' '2019-11-02T09:30:00.000000000'
#  '2019-11-02T16:30:00.000000000' '2019-11-02T07:00:00.000000000'
#  '2019-11-02T09:45:00.000000000' '2019-11-02T10:15:00.000000000'
#  '2019-11-02T11:00:00.000000000' '2019-11-02T12:15:00.000000000'
#  '2019-11-02T22:00:00.000000000' '2019-11-02T06:45:00.000000000'
#  '2019-11-02T13:15:00.000000000' '2019-11-02T15:45:00.000000000'
#  '2019-11-02T17:45:00.000000000' '2019-11-02T12:45:00.000000000'
#  '2019-11-02T02:45:00.000000000' '2019-11-02T09:15:00.000000000'
#  '2019-11-02T20:45:00.000000000' '2019-11-02T06:30:00.000000000'
#  '2019-11-02T18:15:00.000000000' '2019-11-02T08:30:00.000000000'
#  '2019-11-02T10:00:00.000000000' '2019-11-02T10:30:00.000000000'
#  '2019-11-02T12:00:00.000000000' '2019-11-02T13:30:00.000000000'
#  '2019-11-02T14:00:00.000000000' '2019-11-02T14:15:00.000000000'
#  '2019-11-02T10:45:00.000000000' '2019-11-02T07:30:00.000000000'
#  '2019-11-02T08:15:00.000000000' '2019-11-02T00:15:00.000000000'
#  '2019-11-02T00:30:00.000000000' '2019-11-02T07:15:00.000000000'
#  '2019-11-02T06:00:00.000000000' '2019-11-02T11:15:00.000000000'
#  '2019-11-02T12:30:00.000000000' '2019-11-02T13:45:00.000000000'
#  '2019-11-02T14:45:00.000000000' '2019-11-02T19:15:00.000000000'
#  '2019-11-02T15:30:00.000000000' '2019-11-02T05:00:00.000000000'
#  '2019-11-02T05:15:00.000000000' '2019-11-02T05:30:00.000000000'
#  '2019-11-02T05:45:00.000000000' '2019-11-02T06:15:00.000000000'
#  '2019-11-02T08:00:00.000000000' '2019-11-02T17:00:00.000000000'
#  '2019-11-02T18:00:00.000000000' '2019-11-02T18:30:00.000000000'
#  '2019-11-04T02:45:00.000000000' '2019-11-04T03:30:00.000000000'
#  '2019-11-04T03:00:00.000000000' '2019-11-04T01:30:00.000000000'
#  '2019-11-04T06:15:00.000000000' '2019-11-04T23:00:00.000000000'
#  '2019-11-04T04:15:00.000000000' '2019-11-04T02:00:00.000000000'
#  '2019-11-04T02:30:00.000000000' '2019-11-04T22:45:00.000000000'
#  '2019-11-04T23:30:00.000000000']
#
#
# ###########################     Average_RSRP    ###########################
# [ -93.44444444 -140.          -88.         ...  -81.2        -100.7
#  -124.85714286]
#
#
# ###########################     TrafficDirection    ###########################
# ['Downlink' 'Uplink']
#
#
# ###########################     TrafficVolume    ###########################
# [6.218721 0.647324 6.325963 ... 0.029744 0.01076  0.045772]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79614 entries, 0 to 79613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               79614 non-null  datetime64[ns]
#  1   LocationLatitude        79614 non-null  float64
#  2   LocationLongitude       79614 non-null  float64
#  3   RadioConnectionType     79614 non-null  object
#  4   RadioNetworkGeneration  79614 non-null  object
#  5   RSRP                    79614 non-null  int64
#  6   RadioMobileDataEnabled  79614 non-null  object
#  7   DeviceManufacturer      79614 non-null  object
#  8   DeviceName              79614 non-null  object
#  9   time_approxmate         79614 non-null  datetime64[ns]
#  10  Average_RSRP            79614 non-null  float64
#  11  TrafficDirection        79614 non-null  object
#  12  TrafficVolume           79614 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(6)
# memory usage: 8.5+ MB

# %%
# Missing Values
total = result.isnull().sum().sort_values(ascending=False)
percent = (result.isnull().sum()/result.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(25)
# Out:
#                         Total  Percent
# Timestamp                   0      0.0
# LocationLatitude            0      0.0
# LocationLongitude           0      0.0
# RadioConnectionType         0      0.0
# RadioNetworkGeneration      0      0.0
# RSRP                        0      0.0
# RadioMobileDataEnabled      0      0.0
# DeviceManufacturer          0      0.0
# DeviceName                  0      0.0
# time_approxmate             0      0.0
# Average_RSRP                0      0.0
# TrafficDirection            0      0.0
# TrafficVolume               0      0.0

# %%
#check duplicate rows
def check_duplicate(data):
    duplicate = data.duplicated()
    unique_data  = pd.Series(data.shape[0] - duplicate.value_counts())
    duplicate_data = pd.Series(data.shape[0] - duplicate.value_counts()[0])
    unique_data_percent = pd.Series((unique_data/data.shape[0])*100)
    duplicate_data_percent = pd.Series((duplicate_data/data.shape[0])*100)
    dub = pd.concat([unique_data, duplicate_data,unique_data_percent,duplicate_data_percent], axis=1, keys=['Unique Count', 'Duplicate Count','Unique percent','Duplicate Percent'])
    return dub

check_duplicate(result)
# Out:
#        Unique Count  Duplicate Count  Unique percent  Duplicate Percent
# False             0                0             0.0                0.0

# %%
# Save File
result.to_parquet('../data/processed/RSRP_Traffic.parquet')
